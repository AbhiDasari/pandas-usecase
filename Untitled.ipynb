# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
data=pd.read_csv("usecase.csv")

# %%
print(data.head(10))
print(data.columns)
# Out:
#                   TCID STATUS  \
# AppName EXEDATE
# ACM     04.02.19    90   Pass
#         04.03.19    65   Pass
#         04.03.19    38   Pass
#         04.04.19    60   Pass
#         04.04.19   148   Pass
#         04.05.19   171   Pass
#         04.06.19    38   Pass
#         04.07.19   158   Fail
#         04.07.19   122   Pass
#         04.08.19   147   Fail
#
#                                            RCA  (ENV|CODE|DATA|REQ)
# AppName EXEDATE
# ACM     04.02.19                                                NaN
#         04.03.19                                                NaN
#         04.03.19                                                NaN
#         04.04.19                                                NaN
#         04.04.19                                                NaN
#         04.05.19                                                NaN
#         04.06.19                                                NaN
#         04.07.19  STG|for i in range(0,2)|List out of Index [23]...
#         04.07.19                                                NaN
#         04.08.19  UAT|import pandasa as pd|pandas: Package not f...
# Index(['TCID', 'STATUS', 'RCA  (ENV|CODE|DATA|REQ)'], dtype='object')

# %%
data=data.set_index(["AppName","EXEDATE"])

# %%
data=data.sort_index()
print(data)
# Out:
#                   TCID STATUS  \
# AppName EXEDATE
# ACM     04.02.19    90   Pass
#         04.03.19    65   Pass
#         04.03.19    38   Pass
#         04.04.19    60   Pass
#         04.04.19   148   Pass
# ...                ...    ...
# Zomato  09.27.19   112   Pass
#         09.27.19    98   Pass
#         09.28.19    73   Fail
#         09.28.19   140   Fail
#         09.30.19   149   Pass
#
#                                            RCA  (ENV|CODE|DATA|REQ)
# AppName EXEDATE
# ACM     04.02.19                                                NaN
#         04.03.19                                                NaN
#         04.03.19                                                NaN
#         04.04.19                                                NaN
#         04.04.19                                                NaN
# ...                                                             ...
# Zomato  09.27.19                                                NaN
#         09.27.19                                                NaN
#         09.28.19  PROD|import numpy as np|numpy: Package not fou...
#         09.28.19  PROD|import numpy as np|numpy: Package not fou...
#         09.30.19                                                NaN
#
# [2000 rows x 3 columns]

# %%
plt.figure(figsize=(50,10))
plt.plot(data.loc[("ACM",),"STATUS"])
#plt.plot(data.loc[("Zomato",),"STATUS"],color="black")
plt.xticks(rotation=90)
plt.show()
plt.clf()

# %%
data1=data.loc[("ACM",),:]

fail=data1.STATUS=="Fail"
data1=data1[fail]
print(data1.loc[:,"RCA  (ENV|CODE|DATA|REQ)"])
# Out:
# EXEDATE
# 04.07.19    STG|for i in range(0,2)|List out of Index [23]...
# 04.08.19    UAT|import pandasa as pd|pandas: Package not f...
# 04.09.19    DEV|print("a[10]")|No varible named a|retrive ...
# 04.10.19    DEV|print("a[10]")|No varible named a|retrive ...
# 04.12.19    PROD|import numpy as np|numpy: Package not fou...
#                                   ...
# 09.17.19    PROD|import numpy as np|numpy: Package not fou...
# 09.17.19    DEV|print("a[10]")|No varible named a|retrive ...
# 09.22.19    STG|for i in range(0,2)|List out of Index [23]...
# 09.24.19    PROD|import numpy as np|numpy: Package not fou...
# 09.26.19    UAT|import pandasa as pd|pandas: Package not f...
# Name: RCA  (ENV|CODE|DATA|REQ), Length: 89, dtype: object

# %%
data1.loc[:,"RCA  (ENV|CODE|DATA|REQ)"].hist()
plt.xticks(rotation=90)
# Out:
# ([0, 1, 2, 3, 4], <a list of 5 Text xticklabel objects>)
